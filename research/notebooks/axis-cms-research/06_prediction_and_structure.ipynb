# %% [markdown]
# # Prediction and Structure
#
# This notebook explains prediction as local reliability learning in AXIS CMS.
#
# Primary focus:
# - predictive memory
# - context encoding
# - confidence and frustration traces
# - why prediction requires structure in the world

# %%
from _bootstrap import setup_notebook

ROOT = setup_notebook()
