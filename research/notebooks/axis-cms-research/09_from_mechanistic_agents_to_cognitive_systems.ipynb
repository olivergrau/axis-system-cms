# %% [markdown]
# # From Mechanistic Agents to Cognitive Systems
#
# This notebook connects AXIS CMS back to the larger AXIS vision.
#
# Primary focus:
# - what the current systems already demonstrate
# - what is still missing for richer cognition
# - how AXIS CMS functions as an early substrate for future synthetic cognitive systems

# %%
from _bootstrap import setup_notebook

ROOT = setup_notebook()
