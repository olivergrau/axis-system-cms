# %% [markdown]
# # System Composition: A, A+W, C, and C+W
#
# This notebook explains the controlled progression of AXIS systems.
#
# Primary focus:
# - what each system adds
# - reduction properties
# - controlled composition instead of black-box replacement
# - how added mechanisms reshape behavior

# %%
from _bootstrap import setup_notebook

ROOT = setup_notebook()
