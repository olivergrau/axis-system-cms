# %% [markdown]
# # Experiment Series Analysis
#
# This notebook analyzes AXIS experiment series as structured research arguments.
#
# Primary focus:
# - baseline anchors
# - controlled variation
# - metric tradeoffs
# - how series results should be interpreted mechanistically

# %%
from _bootstrap import setup_notebook

ROOT = setup_notebook()
